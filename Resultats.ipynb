# %% [markdown]
# ## Résultats

# %%
import pandas as pd
import os
import numpy as np
import cv2

# %%
def compute_iou(boxA, boxB):
    # Coordonnées de l'intersection
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # Calcul de l'aire d'intersection
    interArea = max(0, xB - xA) * max(0, yB - yA)

    # Aires des bounding boxes
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])

    # IoU
    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

# %%
def compute_center_distance(boxA, boxB):
    centerA = ((boxA[0] + boxA[2]) / 2, (boxA[1] + boxA[3]) / 2)
    centerB = ((boxB[0] + boxB[2]) / 2, (boxB[1] + boxB[3]) / 2)
    
    # Distance Euclidienne
    return np.sqrt((centerA[0] - centerB[0]) ** 2 + (centerA[1] - centerB[1]) ** 2)

# %%
def compute_size_difference(boxA, boxB):
    widthA = boxA[2] - boxA[0]
    heightA = boxA[3] - boxA[1]
    widthB = boxB[2] - boxB[0]
    heightB = boxB[3] - boxB[1]

    width_diff = abs(widthA - widthB) / widthA * 100  # Différence en pourcentage
    height_diff = abs(heightA - heightB) / heightA * 100  # Différence en pourcentage

    return width_diff, height_diff

# %%
def compute_mae(boxA, boxB):
    return np.mean(np.abs(np.array(boxA) - np.array(boxB)))

# %%
def compute_center(box):
    return ((box[0] + box[2]) / 2, (box[1] + box[3]) / 2)

# %%
import os
import numpy as np
from PIL import Image, ImageEnhance

# Paramètres d'ajustement
contrast_factor = 1   # Augmenter le contraste (1.0 = original)
brightness_factor = 1 # Réduire la luminosité
num_occlusions = 0      # Nombre d'occlusions

CF = [0.25, 0.5, 0.75, 1, 1.5, 2, 3, 5]
BF = [0.25, 0.5, 0.75, 1, 1.5, 2, 3, 5]
OCCLUSIONS = [0, 1, 2, 3, 4, 5]

IMAGES = ['bag', 'bear', 'book', 'camel', 'rhino', 'swan']

for ig in IMAGES:
    for num_occlusions in OCCLUSIONS:
        # Dossier contenant les images
        input_folder = f'../../test/{ig}/'
        output_folder = f'../../test/processed/{ig}_occlusions_{num_occlusions}/'

        # Création du dossier de sortie
        os.makedirs(output_folder, exist_ok=True)

        def adjust_contrast(image, factor):
            """Ajuste le contraste de l'image. Factor > 1 augmente le contraste, factor < 1 le réduit."""
            enhancer = ImageEnhance.Contrast(image)
            return enhancer.enhance(factor)

        def adjust_brightness(image, factor):
            """Ajuste la luminosité de l'image. Factor > 1 augmente la luminosité, factor < 1 la réduit."""
            enhancer = ImageEnhance.Brightness(image)
            return enhancer.enhance(factor)

        def add_occlusion(image, num_rectangles=3):
            """Ajoute des occlusions en dessinant des rectangles noirs aléatoires."""
            img_array = np.array(image)
            h, w, _ = img_array.shape

            for _ in range(num_rectangles):
                x1, y1 = np.random.randint(0, w), np.random.randint(0, h)
                x2, y2 = np.random.randint(x1, w), np.random.randint(y1, h)
                img_array[y1:y2, x1:x2] = 0  # Rectangle noir

            return Image.fromarray(img_array)

        # Traitement des images
        for filename in os.listdir(input_folder):
            if filename.lower().endswith((".bmp")):
bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_3/swan-049.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_3/swan-050.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-001.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-002.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-003.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-004.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-005.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-006.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-007.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-008.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-009.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-010.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-011.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-012.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-013.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-014.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-015.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-016.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-017.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-018.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-019.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-020.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-021.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-022.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-023.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-024.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-025.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-026.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-027.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-028.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-029.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-030.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-031.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-032.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-033.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-034.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-035.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-036.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-037.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-038.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-039.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-040.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-041.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-042.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-043.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-044.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-045.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-046.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-047.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-048.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-049.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_4/swan-050.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-001.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-002.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-003.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-004.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-005.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-006.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-007.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-008.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-009.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-010.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-011.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-012.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-013.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-014.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-015.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-016.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-017.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-018.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-019.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-020.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-021.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-022.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-023.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-024.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-025.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-026.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-027.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-028.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-029.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-030.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-031.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-032.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-033.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-034.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-035.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-036.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-037.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-038.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-039.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-040.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-041.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-042.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-043.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-044.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-045.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-046.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-047.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-048.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-049.bmp
# Image traitée et enregistrée : ../../test/processed/swan_occlusions_5/swan-050.bmp
# Traitement terminé.

# %%
all_results = []
ground_truth_files = [
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    '../data/bounding_box_bag.csv', 
    '../data/bounding_box_bear.csv',
    '../data/bounding_box_book.csv',
    '../data/bounding_box_camel.csv',
    '../data/bounding_box_rhino.csv',
    '../data/bounding_box_swan.csv',
    # Ajoute ici d'autres fichiers CSV ground truth
]

predicted_files = [
    '../data/predicted_bb_bag.csv', 
    '../data/predicted_bb_bear.csv',
    '../data/predicted_bb_book.csv',
    '../data/predicted_bb_camel.csv',
    '../data/predicted_bb_rhino.csv',
    '../data/predicted_bb_swan.csv',
        '../data/predicted_bb_bag_contrast_0.25.csv',
    '../data/predicted_bb_bear_contrast_0.25.csv',
    '../data/predicted_bb_book_contrast_0.25.csv',
    '../data/predicted_bb_camel_contrast_0.25.csv',
    '../data/predicted_bb_rhino_contrast_0.25.csv',
    '../data/predicted_bb_swan_contrast_0.25.csv',
    '../data/predicted_bb_bag_contrast_0.5.csv',
    '../data/predicted_bb_bear_contrast_0.5.csv',
    '../data/predicted_bb_book_contrast_0.5.csv',
    '../data/predicted_bb_camel_contrast_0.5.csv',
    '../data/predicted_bb_rhino_contrast_0.5.csv',
    '../data/predicted_bb_swan_contrast_0.5.csv',
    '../data/predicted_bb_bag_contrast_0.75.csv',
    '../data/predicted_bb_bear_contrast_0.75.csv',
    '../data/predicted_bb_book_contrast_0.75.csv',
    '../data/predicted_bb_camel_contrast_0.75.csv',
    '../data/predicted_bb_rhino_contrast_0.75.csv',
    '../data/predicted_bb_swan_contrast_0.75.csv',
    '../data/predicted_bb_bag_contrast_1.5.csv',
    '../data/predicted_bb_bear_contrast_1.5.csv',
    '../data/predicted_bb_book_contrast_1.5.csv',
    '../data/predicted_bb_camel_contrast_1.5.csv',
    '../data/predicted_bb_rhino_contrast_1.5.csv',
    '../data/predicted_bb_swan_contrast_1.5.csv',
    '../data/predicted_bb_bag_contrast_2.csv',
    '../data/predicted_bb_bear_contrast_2.csv',
    '../data/predicted_bb_book_contrast_2.csv',
    '../data/predicted_bb_camel_contrast_2.csv',
    '../data/predicted_bb_rhino_contrast_2.csv',
    '../data/predicted_bb_swan_contrast_2.csv',
    '../data/predicted_bb_bag_contrast_3.csv',
    '../data/predicted_bb_bear_contrast_3.csv',
    '../data/predicted_bb_book_contrast_3.csv',
    '../data/predicted_bb_camel_contrast_3.csv',
    '../data/predicted_bb_rhino_contrast_3.csv',
    '../data/predicted_bb_swan_contrast_3.csv',
    '../data/predicted_bb_bag_contrast_5.csv',
    '../data/predicted_bb_bear_contrast_5.csv',
    '../data/predicted_bb_book_contrast_5.csv',
    '../data/predicted_bb_camel_contrast_5.csv',
    '../data/predicted_bb_rhino_contrast_5.csv',
    '../data/predicted_bb_swan_contrast_5.csv',
    
    ]
# 📂 Parcourir chaque dossier de vidéo
for gt_file, pred_file in zip(ground_truth_files, predicted_files):
    # 📥 Charger les fichiers CSV
    gt_df = pd.read_csv(gt_file, header=None, names=["x1", "y1", "x2", "y2"])
    pred_df = pd.read_csv(pred_file, header=None, names=["x1", "y1", "x2", "y2"])

    if len(gt_df) != len(pred_df):
        print(" Nombre de frames différent pour un meme fichier")
        continue

    # 📊 Calcul des métriques
    ious = []
    distances = []
    width_diffs = []
    height_diffs = []

    for i in range(1,len(gt_df)):
        gt_first_row = gt_df.iloc[i]
        pred_first_row = pred_df.iloc[i]
        iou = compute_iou(
            [int(gt_first_row["x1"]), int(gt_first_row["y1"]), int(gt_first_row["x2"]), int(gt_first_row["y2"])],
            [int(pred_first_row["x1"]), int(pred_first_row["y1"]), int(pred_first_row["x2"]), int(pred_first_row["y2"])]
        )
        dist = compute_center_distance(
            [int(gt_first_row["x1"]), int(gt_first_row["y1"]), int(gt_first_row["x2"]), int(gt_first_row["y2"])],
            [int(pred_first_row["x1"]), int(pred_first_row["y1"]), int(pred_first_row["x2"]), int(pred_first_row["y2"])]
        )
        w_diff, h_diff = compute_size_difference(
            [int(gt_first_row["x1"]), int(gt_first_row["y1"]), int(gt_first_row["x2"]), int(gt_first_row["y2"])],
            [int(pred_first_row["x1"]), int(pred_first_row["y1"]), int(pred_first_row["x2"]), int(pred_first_row["y2"])]
        )

        ious.append(iou)
        distances.append(dist)
        width_diffs.append(w_diff)
        height_diffs.append(h_diff)

    # 📊 Résumé des métriques pour la vidéo
    avg_iou = np.mean(ious)
    avg_distance = np.mean(distances)
    avg_width_diff = np.mean(width_diffs)
    avg_height_diff = np.mean(height_diffs)

    all_results.append([gt_file, pred_file, avg_iou, avg_distance, avg_width_diff, avg_height_diff])

results_df = pd.DataFrame(all_results, columns=["Video File", "Prediction File", "Average IoU", "Average Distance", "Average Percentage Width Diff", "Average Percentage Height Diff"])
output_file = "./results_contrast.csv"
results_df.to_csv(output_file, index=False)

# 📊 Affichage des résultats sous forme de tableau
print(results_df)
# Out:
#                         Video File
# 0     ../data/bounding_box_bag.csv  \
# 1    ../data/bounding_box_bear.csv
# 2    ../data/bounding_box_book.csv
# 3   ../data/bounding_box_camel.csv
# 4   ../data/bounding_box_rhino.csv
# 5    ../data/bounding_box_swan.csv
# 6     ../data/bounding_box_bag.csv
# 7    ../data/bounding_box_bear.csv
# 8    ../data/bounding_box_book.csv
# 9   ../data/bounding_box_camel.csv
# 10  ../data/bounding_box_rhino.csv
# 11   ../data/bounding_box_swan.csv
# 12    ../data/bounding_box_bag.csv
# 13   ../data/bounding_box_bear.csv
# 14   ../data/bounding_box_book.csv
# 15  ../data/bounding_box_camel.csv
# 16  ../data/bounding_box_rhino.csv
# 17   ../data/bounding_box_swan.csv
# 18    ../data/bounding_box_bag.csv
# 19   ../data/bounding_box_bear.csv
# 20   ../data/bounding_box_book.csv
# 21  ../data/bounding_box_camel.csv
# 22  ../data/bounding_box_rhino.csv
# 23   ../data/bounding_box_swan.csv
# 24    ../data/bounding_box_bag.csv
# 25   ../data/bounding_box_bear.csv
# 26   ../data/bounding_box_book.csv
# 27  ../data/bounding_box_camel.csv
# 28  ../data/bounding_box_rhino.csv
# 29   ../data/bounding_box_swan.csv
# 30    ../data/bounding_box_bag.csv
# 31   ../data/bounding_box_bear.csv
# 32   ../data/bounding_box_book.csv
# 33  ../data/bounding_box_camel.csv
# 34  ../data/bounding_box_rhino.csv
# 35   ../data/bounding_box_swan.csv
# 36    ../data/bounding_box_bag.csv
# 37   ../data/bounding_box_bear.csv
# 38   ../data/bounding_box_book.csv
# 39  ../data/bounding_box_camel.csv
# 40  ../data/bounding_box_rhino.csv
# 41   ../data/bounding_box_swan.csv
# 42    ../data/bounding_box_bag.csv
# 43   ../data/bounding_box_bear.csv
# 44   ../data/bounding_box_book.csv
# 45  ../data/bounding_box_camel.csv
# 46  ../data/bounding_box_rhino.csv
# 47   ../data/bounding_box_swan.csv
#
#                                  Prediction File  Average IoU
# 0                   ../data/predicted_bb_bag.csv     0.863222  \
# 1                  ../data/predicted_bb_bear.csv     0.776204
# 2                  ../data/predicted_bb_book.csv     0.380084
# 3                 ../data/predicted_bb_camel.csv     0.597804
# 4                 ../data/predicted_bb_rhino.csv     0.780669
# 5                  ../data/predicted_bb_swan.csv     0.710939
# 6     ../data/predicted_bb_bag_contrast_0.25.csv     0.845250
# 7    ../data/predicted_bb_bear_contrast_0.25.csv     0.861886
# 8    ../data/predicted_bb_book_contrast_0.25.csv     0.156685
# 9   ../data/predicted_bb_camel_contrast_0.25.csv     0.603868
# 10  ../data/predicted_bb_rhino_contrast_0.25.csv     0.578329
# 11   ../data/predicted_bb_swan_contrast_0.25.csv     0.692302
# 12     ../data/predicted_bb_bag_contrast_0.5.csv     0.868854
# 13    ../data/predicted_bb_bear_contrast_0.5.csv     0.806634
# 14    ../data/predicted_bb_book_contrast_0.5.csv     0.330995
# 15   ../data/predicted_bb_camel_contrast_0.5.csv     0.601200
# 16   ../data/predicted_bb_rhino_contrast_0.5.csv     0.733544
# 17    ../data/predicted_bb_swan_contrast_0.5.csv     0.717682
# 18    ../data/predicted_bb_bag_contrast_0.75.csv     0.867879
# 19   ../data/predicted_bb_bear_contrast_0.75.csv     0.793858
# 20   ../data/predicted_bb_book_contrast_0.75.csv     0.405771
# 21  ../data/predicted_bb_camel_contrast_0.75.csv     0.607266
# 22  ../data/predicted_bb_rhino_contrast_0.75.csv     0.764430
# 23   ../data/predicted_bb_swan_contrast_0.75.csv     0.667930
# 24     ../data/predicted_bb_bag_contrast_1.5.csv     0.873158
# 25    ../data/predicted_bb_bear_contrast_1.5.csv     0.770355
# 26    ../data/predicted_bb_book_contrast_1.5.csv     0.364018
# 27   ../data/predicted_bb_camel_contrast_1.5.csv     0.604435
# 28   ../data/predicted_bb_rhino_contrast_1.5.csv     0.748603
# 29    ../data/predicted_bb_swan_contrast_1.5.csv     0.833128
# 30       ../data/predicted_bb_bag_contrast_2.csv     0.856034
# 31      ../data/predicted_bb_bear_contrast_2.csv     0.768250
# 32      ../data/predicted_bb_book_contrast_2.csv     0.324743
# 33     ../data/predicted_bb_camel_contrast_2.csv     0.577663
# 34     ../data/predicted_bb_rhino_contrast_2.csv     0.711484
# 35      ../data/predicted_bb_swan_contrast_2.csv     0.824830
# 36       ../data/predicted_bb_bag_contrast_3.csv     0.819728
# 37      ../data/predicted_bb_bear_contrast_3.csv     0.764115
# 38      ../data/predicted_bb_book_contrast_3.csv     0.322566
# 39     ../data/predicted_bb_camel_contrast_3.csv     0.565125
# 40     ../data/predicted_bb_rhino_contrast_3.csv     0.639412
# 41      ../data/predicted_bb_swan_contrast_3.csv     0.797085
# 42       ../data/predicted_bb_bag_contrast_5.csv     0.696700
# 43      ../data/predicted_bb_bear_contrast_5.csv     0.788179
# 44      ../data/predicted_bb_book_contrast_5.csv     0.441236
# 45     ../data/predicted_bb_camel_contrast_5.csv     0.538115
# 46     ../data/predicted_bb_rhino_contrast_5.csv     0.648264
# 47      ../data/predicted_bb_swan_contrast_5.csv     0.802156
#
#     Average Distance  Average Percentage Width Diff
# 0           4.026938                       7.320582  \
# 1          11.852403                       5.766113
# 2          22.708007                      12.646082
# 3          32.191230                      39.804590
# 4          17.303989                      20.331336
# 5          22.508362                       2.020074
# 6           4.297491                       8.715494
# 7           7.227263                       8.496279
# 8          40.256090                      12.139531
# 9          31.758649                      35.568698
# 10         41.168272                      24.929302
# 11         27.224795                       8.606179
# 12          3.723303                       6.708406
# 13         10.620383                       6.276422
# 14         25.551176                      11.545613
# 15         31.834348                      30.823988
# 16         20.200455                      29.998388
# 17         23.124670                       2.852009
# 18          3.993008                       6.754378
# 19         10.770431                       6.345030
# 20         19.129984                      20.120172
# 21         32.109754                      36.069297
# 22         19.183719                      25.694674
# 23         26.997858                       2.375616
# 24          3.337288                       6.947963
# 25         12.231118                       6.073938
# 26         23.970280                      15.556948
# 27         31.017514                      42.496652
# 28         21.506380                      22.576636
# 29         12.016812                       3.644046
# 30          3.403820                       9.141022
# 31         12.574999                       6.052584
# 32         26.906310                      13.855844
# 33         34.149696                      41.165273
# 34         27.026347                      23.935681
# 35         12.588379                       4.324695
# 36          3.882414                      12.908405
# 37         13.036888                       6.209742
# 38         24.280865                      12.110612
# 39         35.946963                      38.517450
# 40         34.658805                      26.339396
# 41         17.314918                       8.694859
# 42          8.094139                      25.636365
# 43         11.728964                       5.862043
# 44         19.566893                      11.670317
# 45         39.254561                      34.659360
# 46         30.577651                      19.345346
# 47         12.717666                       5.094527
#
#     Average Percentage Height Diff
# 0                         3.440373
# 1                         3.114444
# 2                        38.189951
# 3                        11.406992
# 4                         4.254590
# 5                         3.866414
# 6                         4.675186
# 7                         2.406930
# 8                        12.850930
# 9                         5.546423
# 10                        4.753971
# 11                        0.881367
# 12                        4.087672
# 13                        3.039745
# 14                       38.577969
# 15                        9.850908
# 16                        2.655681
# 17                        0.936271
# 18                        3.056737
# 19                        2.664355
# 20                       44.888894
# 21                       13.627291
# 22                        4.002518
# 23                        1.880208
# 24                        3.167797
# 25                        2.815357
# 26                       40.792478
# 27                        9.105754
# 28                        3.327213
# 29                        2.904938
# 30                        5.367457
# 31                        2.740682
# 32                       35.946779
# 33                        8.402985
# 34                        3.103569
# 35                        4.787844
# 36                        6.657418
# 37                        2.815357
# 38                       60.908534
# 39                       10.686275
# 40                        3.379447
# 41                        1.973315
# 42                       24.066998
# 43                        2.406952
# 44                       31.308903
# 45                       14.592631
# 46                        6.000536
# 47                        7.306531

# %%
def create_tracking_video(image_folder, gt_csv, pred_csv, output_video_path, frame_rate=30, video_size=(640, 480)):
    """
    Crée une vidéo avec le vrai tracking (ground truth) et le tracking prédit.
    
    @param image_folder: Le dossier contenant les images (frames) de la vidéo.
    @param gt_csv: Le fichier CSV contenant les boîtes de ground truth.
    @param pred_csv: Le fichier CSV contenant les boîtes prédites.
    @param output_video_path: Le chemin où enregistrer la vidéo générée.
    @param frame_rate: Le taux de rafraîchissement de la vidéo (en images par seconde).
    @param video_size: La taille de la vidéo (largeur, hauteur).
    """
    
    # Charger les données ground truth et predicted
    gt_df = pd.read_csv(gt_csv, header=None, names=["x1", "y1", "x2", "y2"])
    pred_df = pd.read_csv(pred_csv, header=None, names=["x1", "y1", "x2", "y2"])

    # S'assurer que le nombre de frames est identique dans les deux fichiers CSV
    if len(gt_df) != len(pred_df):
        print("Le nombre de frames ne correspond pas entre les fichiers ground truth et predicted.")
        return

    # Liste des fichiers d'image triée
    image_files = sorted(os.listdir(image_folder))
    
    # Initialiser la vidéo de sortie (en format AVI avec codec MJPEG)
    fourcc = cv2.VideoWriter_fourcc(*'MJPG')  # Codec MJPEG utilisé pour les vidéos AVI
    out_video = cv2.VideoWriter(output_video_path, fourcc, frame_rate, video_size)

    # Pour chaque frame, dessiner les boîtes de ground truth et prédictions
    for i, image_file in enumerate(image_files):
        if not image_file.endswith(".bmp"):  # Vérifier si l'image est bien au format .bmp
            continue
        
        # Charger l'image
        image_path = os.path.join(image_folder, image_file)
        frame = cv2.imread(image_path)

        # Vérifier que l'image a bien été chargée
        if frame is None:
            print(f"Erreur lors du chargement de l'image {image_file}.")
            continue

        # Obtenir les dimensions d'origine de l'image
        original_height, original_width = frame.shape[:2]

        # Redimensionner l'image pour qu'elle corresponde à la taille de la vidéo
        frame_resized = cv2.resize(frame, video_size)
        resized_height, resized_width = frame_resized.shape[:2]

        # Calculer le facteur de redimensionnement
        scale_x = resized_width / original_width
        scale_y = resized_height / original_height

        # Récupérer les coordonnées des boxes ground truth et predicted pour cette frame
        gt_box = gt_df.iloc[i]
        pred_box = pred_df.iloc[i]

        # Appliquer le redimensionnement aux coordonnées des boîtes
        gt_x1, gt_y1, gt_x2, gt_y2 = (
            int(gt_box["x1"] * scale_x),
            int(gt_box["y1"] * scale_y),
            int(gt_box["x2"] * scale_x),
            int(gt_box["y2"] * scale_y),
        )
        pred_x1, pred_y1, pred_x2, pred_y2 = (
            int(pred_box["x1"] * scale_x),
            int(pred_box["y1"] * scale_y),
            int(pred_box["x2"] * scale_x),
            int(pred_box["y2"] * scale_y),
        )

        # Dessiner les boîtes de ground truth (en vert)
        cv2.rectangle(frame_resized, (gt_x1, gt_y1), (gt_x2, gt_y2), (0, 255, 0), 2)
        cv2.putText(frame_resized, "Ground Truth", (gt_x1, gt_y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        # Dessiner les boîtes prédites (en rouge)
        cv2.rectangle(frame_resized, (pred_x1, pred_y1), (pred_x2, pred_y2), (0, 0, 255), 2)
        cv2.putText(frame_resized, "Predicted", (pred_x1, pred_y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

        # Ajouter l'image au fichier vidéo de sortie
        out_video.write(frame_resized)

    # Libérer les ressources vidéo
    out_video.release()
    print(f"Vidéo de tracking générée : {output_video_path}")

# Exemple d'utilisation :
image_folder = '../../test/rhino'  # Dossier des images (frames de la vidéo)
gt_csv = 'ground_truth/bounding_box_rhino.csv'  # Fichier CSV des ground truth
pred_csv = 'predicted/bounding_box_rhino_predicted.csv'  # Fichier CSV des prédictions
output_video_path = 'rhino_video.avi'  # Chemin du fichier vidéo de sortie en AVI

create_tracking_video(image_folder, gt_csv, pred_csv, output_video_path)
# Out:
# Vidéo de tracking générée : rhino_video.avi

# %%
# Generate centroid file for each video


predicted_files = [
    '../data/bounding_box_cow_predicted.csv',
    '../data/bounding_box_fish_predicted.csv',
    '../data/bounding_box_octopus_predicted.csv',
]

img = {'../data/bounding_box_cow_predicted.csv' : 'cow', '../data/bounding_box_fish_predicted.csv' : 'fish', '../data/bounding_box_octopus_predicted.csv' : 'octopus'}

for pred_file in predicted_files:
    # Charger le fichier CSV
    pred_df = pd.read_csv(pred_file, header=None, names=["x1", "y1", "x2", "y2"])

    # Créer un DataFrame pour les coordonnées des centroids
    centroids = []

    # Calculer les coordonnées des centroids pour chaque frame
    for i in range(2,len(pred_df)):
        pred_row = pred_df.iloc[i]
        x = (int(pred_row["x1"]) + int(pred_row["x2"])) / 2
        y = (int(pred_row["y1"]) + int(pred_row["y2"])) / 2
        centroids.append([x, y])
    
    # Sauvegarder les coordonnées des centroids dans un fichier CSV
    output_path = f'./centroids_{img[pred_file]}.npy'
    output_file = np.save(output_path, centroids)
